# %% [markdown]
# # Product Recommendation with Feathr
#
# This notebook illustrates the use of Feathr Feature Store to create a model that predict users' rating for different products for a e-commerce website.
#
# ### Model Problem Statement
# The e-commerce website has collected past user ratings for various products. The website also collected data about user and product, like user age, product category etc. Now we want to predict users' product rating for new product so that we can recommend the new product to users that give a high rating for those products.
#
# ### Feature Creation Illustration
# In this example, our observation data has compound entity key where a record is uniquely identified by `user_id` and `product_id`. With that, we can think about three types of features:
# 1. **User features** that are different for different users but are the same for different products. For example, user age is different for different users but it's product-agnostic.
# 2. **Product features** that are different for different products but are the same for all the users.
# 3. **User-to-product** features that are different for different users AND different products. For example, a feature to represent if the user has bought this product before or not.
#
# In this example, we will focus on the first two types of features. After we train a model based on those features, we predict the product ratings that users will give for the products.
#
# The feature creation flow is as below:
# ![Feature Flow](https://github.com/feathr-ai/feathr/blob/main/docs/images/product_recommendation_advanced.jpg?raw=true)

# %% [markdown]
# ## 2. Config Feathr Client

# %%
import glob
import os
import tempfile
from datetime import datetime, timedelta
from math import sqrt

import pandas as pd
from pyspark.sql import DataFrame
from interpret.provider import InlineProvider
from interpret import set_visualize_provider

set_visualize_provider(InlineProvider())

import feathr
from feathr import (
    FeathrClient,
    BOOLEAN, FLOAT, INT32, ValueType,
    Feature, DerivedFeature, FeatureAnchor,
    BackfillTime, MaterializationSettings,
    FeatureQuery, ObservationSettings,
    RedisSink,
    INPUT_CONTEXT, HdfsSource,
    WindowAggTransformation,
    TypedKey,
)
from feathr.datasets.constants import (
    PRODUCT_RECOMMENDATION_USER_OBSERVATION_URL,
    PRODUCT_RECOMMENDATION_USER_PROFILE_URL,
    PRODUCT_RECOMMENDATION_USER_PURCHASE_HISTORY_URL,
    PRODUCT_RECOMMENDATION_PRODUCT_DETAIL_URL,
)
from feathr.datasets.utils import maybe_download
from feathr.utils.config import generate_config
from feathr.utils.job_utils import get_result_df

print(f"Feathr version: {feathr.__version__}")
# Out:
# Feathr version: 1.0.0

# %%
PROJECT_NAME = "product_recommendation"
os.environ['SPARK_LOCAL_IP'] = "127.0.0.1"

# %% [markdown]
# ### Initialize Feathr Client

# %%
client = FeathrClient(config_path=os.getenv("FEATHR_CONFIG_PATH"))
# Out:
# 2023-08-30 22:36:16.967 | INFO     | feathr.utils._env_config_reader:get:62 - Config secrets__azure_key_vault__name is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2023-08-30 22:36:16.968 | INFO     | feathr.utils._env_config_reader:get:62 - Config offline_store__adls__adls_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2023-08-30 22:36:16.969 | INFO     | feathr.utils._env_config_reader:get:62 - Config offline_store__wasb__wasb_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2023-08-30 22:36:16.969 | INFO     | feathr.utils._env_config_reader:get:62 - Config offline_store__jdbc__jdbc_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2023-08-30 22:36:16.970 | INFO     | feathr.utils._env_config_reader:get:62 - Config offline_store__snowflake__snowflake_enabled is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2023-08-30 22:36:16.970 | INFO     | feathr.utils._env_config_reader:get:62 - Config feature_registry__purview__purview_name is not found in the environment variable, configuration file, or the remote key value store. Returning the default value: None.
# 2023-08-30 22:36:16.971 | INFO     | feathr.client:__init__:213 - Feathr client 1.0.0 initialized successfully.

# %% [markdown]
# ## 3. Prepare Datasets

# %%
# Download datasets
WORKING_DIR = PROJECT_NAME
user_observation_file_path = f"{WORKING_DIR}/user_observation.csv"
user_profile_file_path = f"{WORKING_DIR}/user_profile.csv"
user_purchase_history_file_path = f"{WORKING_DIR}/user_purchase_history.csv"
product_detail_file_path = f"{WORKING_DIR}/product_detail.csv"
maybe_download(
    src_url=PRODUCT_RECOMMENDATION_USER_OBSERVATION_URL,
    dst_filepath=user_observation_file_path,
)
maybe_download(
    src_url=PRODUCT_RECOMMENDATION_USER_PROFILE_URL,
    dst_filepath=user_profile_file_path,
)
maybe_download(
    src_url=PRODUCT_RECOMMENDATION_USER_PURCHASE_HISTORY_URL,
    dst_filepath=user_purchase_history_file_path,
)
maybe_download(
    src_url=PRODUCT_RECOMMENDATION_PRODUCT_DETAIL_URL,
    dst_filepath=product_detail_file_path,
)

# In local mode, we can use the same data path as the source.
user_observation_source_path = user_observation_file_path
user_profile_source_path = user_profile_file_path
user_purchase_history_source_path = user_purchase_history_file_path
product_detail_source_path = product_detail_file_path

# %% [markdown]
# ## 4. Define Sharable Features using Feathr API
#
# ### Understand raw datasets
# We have three datasets to work with:
# * Observation dataset (a.k.a. labeled dataset)
# * User profile
# * User purchase history
# * Product details

# %%
# Observation dataset
# Observation dataset usually comes with a event_timestamp to denote when the observation happened.
# The label here is product_rating. Our model objective is to predict a user's rating for this product.
pd.read_csv(user_observation_file_path).head()
# Out:
#    user_id  product_id event_timestamp  product_rating
# 0        1           1      2021-04-01               4
# 1        1           2      2021-04-01               4
# 2        1           3      2021-04-01               4
# 3        1           4      2021-04-01               4
# 4        1           5      2021-04-01               4

# %%
# User profile dataset
# Used to generate user features
pd.read_csv(user_profile_file_path).head()
# Out:
#    user_id  gender  age  gift_card_balance  number_of_credit_cards state  \
# 0        1       1   22                100                       0    CA
# 1        2       2   17                300                       1    CA
# 2        3       1   40                  0                       2    WA
# 3        4       1   25                100                       3    WA
# 4        5       1   33                  0                       2    PA
#
#    tax_rate
# 0       7.5
# 1       7.5
# 2       7.5
# 3       7.5
# 4       0.0

# %%
# User purchase history dataset.
# Used to generate user features. This is activity type data, so we need to use aggregation to generate features.
pd.read_csv(user_purchase_history_file_path).head()
# Out:
#    user_id purchase_date  purchase_amount
# 0        1    2021-01-01             0.33
# 1        1    2021-03-03           574.35
# 2        1    2021-01-03           796.07
# 3        2    2021-01-04           342.15
# 4        2    2021-03-05           280.46

# %%
# Product detail dataset.
# Used to generate product features.
pd.read_csv(product_detail_file_path).head()
# Out:
#    product_id  category  price  quantity  recent_sold made_in_state  discount
# 0           1         1     22       100            0            CA       7.5
# 1           2         2     17       300            1            CA       7.5
# 2           3         1     40         0            2            WA       7.5
# 3           4         1     25       100            3            WA       7.5
# 4           5         1     33         0            2            PA       0.0

# %% [markdown]
# ### What's a feature in Feathr
# A feature is an individual measurable property or characteristic of a phenomenon which is sometimes time-sensitive.
#
# In Feathr, a feature is defined by the following characteristics:
# * The typed key (a.k.a. entity id): identifies the subject of feature, e.g. a user id of 123, a product id of SKU234456.
# * The feature name: the unique identifier of the feature, e.g. user_age, total_spending_in_30_days.
# * The feature value: the actual value of that aspect at a particular time, e.g. the feature value of the person's age is 30 at year 2022.
# * The timestamp: this indicates when the event happened. For example, the user purchased certain product on a certain timestamp. This is usually used for point-in-time join.
#
# You can feel that this is defined from a feature consumer (a person who wants to use a feature) perspective. It only tells us what a feature is like. In later sections, you can see how a feature consumer can access the features in a very simple way.
#
# To define how to produce the feature, we need to specify:
# * Feature source: what source data that this feature is based on
# * Transformation: what transformation is used to transform the source data into feature. Transformation can be optional when you just want to take a column out from the source data.
#
# (For more details on feature definition, please refer to the [Feathr Feature Definition Guide](https://feathr-ai.github.io/feathr/concepts/feature-definition.html).)

# %% [markdown]
# Note: in some cases, such as features defined on top of request data, may have no entity key or timestamp.
# It is merely a function/transformation executing against request data at runtime.
# For example, the day of week of the request, which is calculated by converting the request UNIX timestamp.
# (We won't cover this in the tutorial.)

# %% [markdown]
# ### Define Sources Section with UDFs
#
# A feature is called an anchored feature when the feature is directly extracted from the source data, rather than computed on top of other features. The latter case is called derived feature.
#
# A [feature source](https://feathr.readthedocs.io/en/latest/#feathr.Source) is needed for anchored features that describes the raw data in which the feature values are computed from. See the python documentation to get the details on each input column.
#
# See [the python API documentation](https://feathr.readthedocs.io/en/latest/#feathr.HdfsSource) to get the details of each input fields.

# %%
def feathr_udf_preprocessing(df: DataFrame) -> DataFrame:
    from pyspark.sql.functions import col

    return df.withColumn("tax_rate_decimal", col("tax_rate") / 100)

batch_source = HdfsSource(
    name="userProfileData",
    path=user_profile_source_path,
    preprocessing=feathr_udf_preprocessing,
)

# %%
# Let's define some features for users so our recommendation can be customized for users.
user_id = TypedKey(
    key_column="user_id",
    key_column_type=ValueType.INT32,
    description="user id",
    full_name="product_recommendation.user_id",
)

feature_user_age = Feature(
    name="feature_user_age",
    key=user_id,
    feature_type=INT32,
    transform="age",
)
feature_user_tax_rate = Feature(
    name="feature_user_tax_rate",
    key=user_id,
    feature_type=FLOAT,
    transform="tax_rate_decimal",
)
feature_user_gift_card_balance = Feature(
    name="feature_user_gift_card_balance",
    key=user_id,
    feature_type=FLOAT,
    transform="gift_card_balance",
)
feature_user_has_valid_credit_card = Feature(
    name="feature_user_has_valid_credit_card",
    key=user_id,
    feature_type=BOOLEAN,
    transform="number_of_credit_cards > 0",
)

features = [
    feature_user_age,
    feature_user_tax_rate,
    feature_user_gift_card_balance,
    feature_user_has_valid_credit_card,
]

user_feature_anchor = FeatureAnchor(
    name="anchored_features", source=batch_source, features=features
)

# %%
# Let's define some features for the products so our recommendation can be customized for products.
product_batch_source = HdfsSource(
    name="productProfileData",
    path=product_detail_source_path,
)

product_id = TypedKey(
    key_column="product_id",
    key_column_type=ValueType.INT32,
    description="product id",
    full_name="product_recommendation.product_id",
)

feature_product_quantity = Feature(
    name="feature_product_quantity",
    key=product_id,
    feature_type=FLOAT,
    transform="quantity",
)
feature_product_price = Feature(
    name="feature_product_price", key=product_id, feature_type=FLOAT, transform="price"
)

product_features = [feature_product_quantity, feature_product_price]

product_feature_anchor = FeatureAnchor(
    name="product_anchored_features",
    source=product_batch_source,
    features=product_features,
)

# %% [markdown]
# ### Define window aggregation features
#
# [Window aggregation](https://en.wikipedia.org/wiki/Window_function_%28SQL%29) helps us to create more powerful features by compressing large amount of information. For example, we can compute *average purchase amount over the last 90 days* from the purchase history to capture user's recent consumption trend.
#
# To create window aggregation features, we define `WindowAggTransformation` with following arguments:
# 1. `agg_expr`: the field/column you want to aggregate. It can be an ANSI SQL expression, e.g. `cast_float(purchase_amount)` to cast `str` type values to `float`.
# 2. `agg_func`: the aggregation function, e.g. `AVG`. See below table for the full list of supported functions.
# 3. `window`: the aggregation window size, e.g. `90d` to aggregate over the 90 days.
#
# | Aggregation Type | Input Type | Description |
# | --- | --- | --- |
# | `SUM`, `COUNT`, `MAX`, `MIN`, `AVG` | Numeric | Applies the the numerical operation on the numeric inputs. |
# | `MAX_POOLING`, `MIN_POOLING`, `AVG_POOLING`	| Numeric Vector | Applies the max/min/avg operation on a per entry basis for a given a collection of numbers. |
# | `LATEST` | Any | Returns the latest not-null values from within the defined time window. |
#
# After you have defined features and sources, bring them together to build an anchor:
#
# > Note that if the features comes directly from the observation data, the `source` argument should be `INPUT_CONTEXT` to indicate the source of the anchor is the observation data.

# %%
purchase_history_data = HdfsSource(
    name="purchase_history_data",
    path=user_purchase_history_source_path,
    event_timestamp_column="purchase_date",
    timestamp_format="yyyy-MM-dd",
)

agg_features = [
    Feature(
        name="feature_user_avg_purchase_for_90days",
        key=user_id,
        feature_type=FLOAT,
        transform=WindowAggTransformation(
            agg_expr="cast_float(purchase_amount)", agg_func="AVG", window="90d"
        ),
    )
]

user_agg_feature_anchor = FeatureAnchor(
    name="aggregationFeatures", source=purchase_history_data, features=agg_features
)

# %% [markdown]
# ### Derived Features Section
# Derived features are the features that are computed from other features. They could be computed from anchored features or other derived features.

# %%
derived_features = [
    DerivedFeature(
        name="feature_user_purchasing_power",
        key=user_id,
        feature_type=FLOAT,
        input_features=[feature_user_gift_card_balance, feature_user_has_valid_credit_card],
        transform="feature_user_gift_card_balance + if(boolean(feature_user_has_valid_credit_card), 100, 0)",
    )
]

# %% [markdown]
# ### Build features
#
# Lastly, we need to build those features so that it can be consumed later. Note that we have to build both the "anchor" and the "derived" features which is not anchored to a source.

# %%
client.build_features(
    anchor_list=[user_agg_feature_anchor, user_feature_anchor, product_feature_anchor],
    derived_feature_list=derived_features,
)

# %% [markdown]
# ## 5. Create Training Data using Point-in-Time Correct Feature join
#
# To create a training dataset using Feathr, we need to provide a **feature join settings** to specify what features and how these features should be joined to the observation data.
#
# Also note that since a `FeatureQuery` accepts features of the same join key, we define two query objects, one for `user_id` key and the other one for `product_id` and pass them together to compute offline features.
#
# To learn more on this topic, please refer to [Point-in-time Correctness document](https://feathr-ai.github.io/feathr/concepts/point-in-time-join.html).

# %%
user_feature_query = FeatureQuery(
    feature_list=[feat.name for feat in features + agg_features + derived_features],
    key=user_id,
)

product_feature_query = FeatureQuery(
    feature_list=[feat.name for feat in product_features],
    key=product_id,
)

settings = ObservationSettings(
    observation_path=user_observation_source_path,
    event_timestamp_column="event_timestamp",
    timestamp_format="yyyy-MM-dd",
)
client.get_offline_features(
    observation_settings=settings,
    feature_query=[user_feature_query, product_feature_query],
    output_path=user_profile_source_path.rpartition("/")[0] + f"/product_recommendation_features.avro",
)
client.wait_job_to_finish(timeout_sec=100)
# Out:
# 2023-08-30 22:36:22.236 | WARNING  | feathr.spark_provider._localspark_submission:submit_feathr_job:78 - Local Spark Mode only support basic params right now and should be used only for testing purpose.
# 2023-08-30 22:36:22.237 | INFO     | feathr.spark_provider._localspark_submission:_get_debug_file_name:287 - Spark log path is debug/local_spark_feathr_feature_join_job20230830223622
# 2023-08-30 22:36:22.238 | INFO     | feathr.spark_provider._localspark_submission:_init_args:262 - Spark job: local_spark_feathr_feature_join_job is running on local spark with master: spark://spark-master:7077.
# 2023-08-30 22:36:22.250 | INFO     | feathr.spark_provider._localspark_submission:submit_feathr_job:142 - Detail job stdout and stderr are in debug/local_spark_feathr_feature_join_job20230830223622/log.
# 2023-08-30 22:36:22.252 | INFO     | feathr.spark_provider._localspark_submission:submit_feathr_job:152 - Local Spark job submit with pid: 4282.
# 2023-08-30 22:36:22.253 | INFO     | feathr.spark_provider._localspark_submission:wait_for_completion:162 - 1 local spark job(s) in this Launcher, only the latest will be monitored.
# 2023-08-30 22:36:22.254 | INFO     | feathr.spark_provider._localspark_submission:wait_for_completion:163 - Please check auto generated spark command in debug/local_spark_feathr_feature_join_job20230830223622/command.sh and detail logs in debug/local_spark_feathr_feature_join_job20230830223622/log.
# x
# 2023-08-30 22:36:53.287 | WARNING  | feathr.spark_provider._localspark_submission:wait_for_completion:212 - Spark job with pid 4282 is not successful. Spark Logs:
# 2023-08-30 22:36:53.291 | ERROR    | feathr.spark_provider._localspark_submission:wait_for_completion:215 - :: loading settings :: url = jar:file:/usr/local/spark-3.3.0-bin-hadoop3/jars/ivy-2.5.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# 23/08/30 22:36:34 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Feathr Pyspark job started.
# 23/08/30 22:36:36 INFO SparkContext: Running Spark version 3.3.0
# 23/08/30 22:36:36 INFO ResourceUtils: ==============================================================
# 23/08/30 22:36:36 INFO ResourceUtils: No custom resources configured for spark.driver.
# 23/08/30 22:36:36 INFO ResourceUtils: ==============================================================
# 23/08/30 22:36:36 INFO SparkContext: Submitted application: FeathrPyspark
# 23/08/30 22:36:36 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 23/08/30 22:36:36 INFO ResourceProfile: Limiting resource is cpu
# 23/08/30 22:36:36 INFO ResourceProfileManager: Added ResourceProfile id: 0
# 23/08/30 22:36:36 INFO SecurityManager: Changing view acls to: jovyan
# 23/08/30 22:36:36 INFO SecurityManager: Changing modify acls to: jovyan
# 23/08/30 22:36:36 INFO SecurityManager: Changing view acls groups to:
# 23/08/30 22:36:36 INFO SecurityManager: Changing modify acls groups to:
# 23/08/30 22:36:36 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(jovyan); groups with view permissions: Set(); users  with modify permissions: Set(jovyan); groups with modify permissions: Set()
# 23/08/30 22:36:36 INFO Utils: Successfully started service 'sparkDriver' on port 40393.
# 23/08/30 22:36:36 INFO SparkEnv: Registering MapOutputTracker
# 23/08/30 22:36:36 INFO SparkEnv: Registering BlockManagerMaster
# 23/08/30 22:36:36 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 23/08/30 22:36:36 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 23/08/30 22:36:36 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
# 23/08/30 22:36:36 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-ae5413c0-076f-4619-8e7b-1bfe42a3746b
# 23/08/30 22:36:36 INFO MemoryStore: MemoryStore started with capacity 434.4 MiB
# 23/08/30 22:36:36 INFO SparkEnv: Registering OutputCommitCoordinator
# 23/08/30 22:36:36 INFO Utils: Successfully started service 'SparkUI' on port 4040.
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-avro_2.12-3.3.0.jar at spark://localhost:40393/jars/org.apache.spark_spark-avro_2.12-3.3.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar at spark://localhost:40393/jars/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar at spark://localhost:40393/jars/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.logging.log4j_log4j-core-2.17.2.jar at spark://localhost:40393/jars/org.apache.logging.log4j_log4j-core-2.17.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.typesafe_config-1.3.4.jar at spark://localhost:40393/jars/com.typesafe_config-1.3.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar at spark://localhost:40393/jars/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-common-2.7.7.jar at spark://localhost:40393/jars/org.apache.hadoop_hadoop-common-2.7.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-azure-3.2.0.jar at spark://localhost:40393/jars/org.apache.hadoop_hadoop-azure-3.2.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.avro_avro-1.8.2.jar at spark://localhost:40393/jars/org.apache.avro_avro-1.8.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.xbean_xbean-asm6-shaded-4.10.jar at spark://localhost:40393/jars/org.apache.xbean_xbean-asm6-shaded-4.10.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.1.3.jar at spark://localhost:40393/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.1.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-eventhubs-spark_2.12-2.3.21.jar at spark://localhost:40393/jars/com.microsoft.azure_azure-eventhubs-spark_2.12-2.3.21.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.kafka_kafka-clients-3.1.0.jar at spark://localhost:40393/jars/org.apache.kafka_kafka-clients-3.1.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.guava_guava-31.1-jre.jar at spark://localhost:40393/jars/com.google.guava_guava-31.1-jre.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/it.unimi.dsi_fastutil-8.1.1.jar at spark://localhost:40393/jars/it.unimi.dsi_fastutil-8.1.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.mvel_mvel2-2.2.8.Final.jar at spark://localhost:40393/jars/org.mvel_mvel2-2.2.8.Final.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.module_jackson-module-scala_2.12-2.13.3.jar at spark://localhost:40393/jars/com.fasterxml.jackson.module_jackson-module-scala_2.12-2.13.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-yaml-2.12.6.jar at spark://localhost:40393/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-yaml-2.12.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar at spark://localhost:40393/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.jasonclawson_jackson-dataformat-hocon-1.1.0.jar at spark://localhost:40393/jars/com.jasonclawson_jackson-dataformat-hocon-1.1.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.redislabs_spark-redis_2.12-3.1.0.jar at spark://localhost:40393/jars/com.redislabs_spark-redis_2.12-3.1.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.protobuf_protobuf-java-3.19.4.jar at spark://localhost:40393/jars/com.google.protobuf_protobuf-java-3.19.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/net.snowflake_snowflake-jdbc-3.13.18.jar at spark://localhost:40393/jars/net.snowflake_snowflake-jdbc-3.13.18.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/net.snowflake_spark-snowflake_2.12-2.10.0-spark_3.2.jar at spark://localhost:40393/jars/net.snowflake_spark-snowflake_2.12-2.10.0-spark_3.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.commons_commons-lang3-3.12.0.jar at spark://localhost:40393/jars/org.apache.commons_commons-lang3-3.12.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.xerial_sqlite-jdbc-3.36.0.3.jar at spark://localhost:40393/jars/org.xerial_sqlite-jdbc-3.36.0.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.github.changvvb_jackson-module-caseclass_2.12-1.1.1.jar at spark://localhost:40393/jars/com.github.changvvb_jackson-module-caseclass_2.12-1.1.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.azure.cosmos.spark_azure-cosmos-spark_3-1_2-12-4.11.1.jar at spark://localhost:40393/jars/com.azure.cosmos.spark_azure-cosmos-spark_3-1_2-12-4.11.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.eclipse.jetty_jetty-util-9.3.24.v20180605.jar at spark://localhost:40393/jars/org.eclipse.jetty_jetty-util-9.3.24.v20180605.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-io_commons-io-2.6.jar at spark://localhost:40393/jars/commons-io_commons-io-2.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-storage-8.6.4.jar at spark://localhost:40393/jars/com.microsoft.azure_azure-storage-8.6.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.tukaani_xz-1.8.jar at spark://localhost:40393/jars/org.tukaani_xz-1.8.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.spark-project.spark_unused-1.0.0.jar at spark://localhost:40393/jars/org.spark-project.spark_unused-1.0.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar at spark://localhost:40393/jars/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.slf4j_slf4j-log4j12-1.7.10.jar at spark://localhost:40393/jars/org.slf4j_slf4j-log4j12-1.7.10.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-annotations-2.7.7.jar at spark://localhost:40393/jars/org.apache.hadoop_hadoop-annotations-2.7.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.inject.extensions_guice-servlet-3.0.jar at spark://localhost:40393/jars/com.google.inject.extensions_guice-servlet-3.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/io.netty_netty-3.6.2.Final.jar at spark://localhost:40393/jars/io.netty_netty-3.6.2.Final.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-yarn-api-2.7.7.jar at spark://localhost:40393/jars/org.apache.hadoop_hadoop-yarn-api-2.7.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/javax.xml.bind_jaxb-api-2.2.2.jar at spark://localhost:40393/jars/javax.xml.bind_jaxb-api-2.2.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-lang_commons-lang-2.6.jar at spark://localhost:40393/jars/commons-lang_commons-lang-2.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/javax.servlet_servlet-api-2.5.jar at spark://localhost:40393/jars/javax.servlet_servlet-api-2.5.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.mortbay.jetty_jetty-util-6.1.26.jar at spark://localhost:40393/jars/org.mortbay.jetty_jetty-util-6.1.26.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.sun.jersey_jersey-core-1.9.jar at spark://localhost:40393/jars/com.sun.jersey_jersey-core-1.9.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.sun.jersey_jersey-client-1.9.jar at spark://localhost:40393/jars/com.sun.jersey_jersey-client-1.9.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.codehaus.jackson_jackson-core-asl-1.9.13.jar at spark://localhost:40393/jars/org.codehaus.jackson_jackson-core-asl-1.9.13.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.codehaus.jackson_jackson-mapper-asl-1.9.13.jar at spark://localhost:40393/jars/org.codehaus.jackson_jackson-mapper-asl-1.9.13.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.codehaus.jackson_jackson-jaxrs-1.9.13.jar at spark://localhost:40393/jars/org.codehaus.jackson_jackson-jaxrs-1.9.13.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.codehaus.jackson_jackson-xc-1.9.13.jar at spark://localhost:40393/jars/org.codehaus.jackson_jackson-xc-1.9.13.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-logging_commons-logging-1.1.3.jar at spark://localhost:40393/jars/commons-logging_commons-logging-1.1.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-cli_commons-cli-1.2.jar at spark://localhost:40393/jars/commons-cli_commons-cli-1.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.inject_guice-3.0.jar at spark://localhost:40393/jars/com.google.inject_guice-3.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.sun.jersey_jersey-server-1.9.jar at spark://localhost:40393/jars/com.sun.jersey_jersey-server-1.9.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.sun.jersey_jersey-json-1.9.jar at spark://localhost:40393/jars/com.sun.jersey_jersey-json-1.9.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.sun.jersey.contribs_jersey-guice-1.9.jar at spark://localhost:40393/jars/com.sun.jersey.contribs_jersey-guice-1.9.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/log4j_log4j-1.2.17.jar at spark://localhost:40393/jars/log4j_log4j-1.2.17.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/javax.xml.stream_stax-api-1.0-2.jar at spark://localhost:40393/jars/javax.xml.stream_stax-api-1.0-2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/javax.activation_activation-1.1.jar at spark://localhost:40393/jars/javax.activation_activation-1.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/javax.inject_javax.inject-1.jar at spark://localhost:40393/jars/javax.inject_javax.inject-1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/aopalliance_aopalliance-1.0.jar at spark://localhost:40393/jars/aopalliance_aopalliance-1.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.sonatype.sisu.inject_cglib-2.2.1-v20090111.jar at spark://localhost:40393/jars/org.sonatype.sisu.inject_cglib-2.2.1-v20090111.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/asm_asm-3.2.jar at spark://localhost:40393/jars/asm_asm-3.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.codehaus.jettison_jettison-1.1.jar at spark://localhost:40393/jars/org.codehaus.jettison_jettison-1.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.sun.xml.bind_jaxb-impl-2.2.3-1.jar at spark://localhost:40393/jars/com.sun.xml.bind_jaxb-impl-2.2.3-1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.commons_commons-math3-3.1.1.jar at spark://localhost:40393/jars/org.apache.commons_commons-math3-3.1.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/xmlenc_xmlenc-0.52.jar at spark://localhost:40393/jars/xmlenc_xmlenc-0.52.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-httpclient_commons-httpclient-3.1.jar at spark://localhost:40393/jars/commons-httpclient_commons-httpclient-3.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-net_commons-net-3.1.jar at spark://localhost:40393/jars/commons-net_commons-net-3.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-collections_commons-collections-3.2.2.jar at spark://localhost:40393/jars/commons-collections_commons-collections-3.2.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.mortbay.jetty_jetty-6.1.26.jar at spark://localhost:40393/jars/org.mortbay.jetty_jetty-6.1.26.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.mortbay.jetty_jetty-sslengine-6.1.26.jar at spark://localhost:40393/jars/org.mortbay.jetty_jetty-sslengine-6.1.26.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/net.java.dev.jets3t_jets3t-0.9.0.jar at spark://localhost:40393/jars/net.java.dev.jets3t_jets3t-0.9.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-configuration_commons-configuration-1.6.jar at spark://localhost:40393/jars/commons-configuration_commons-configuration-1.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-auth-2.7.7.jar at spark://localhost:40393/jars/org.apache.hadoop_hadoop-auth-2.7.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.jcraft_jsch-0.1.54.jar at spark://localhost:40393/jars/com.jcraft_jsch-0.1.54.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.curator_curator-client-2.7.1.jar at spark://localhost:40393/jars/org.apache.curator_curator-client-2.7.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.curator_curator-recipes-2.7.1.jar at spark://localhost:40393/jars/org.apache.curator_curator-recipes-2.7.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.htrace_htrace-core-3.1.0-incubating.jar at spark://localhost:40393/jars/org.apache.htrace_htrace-core-3.1.0-incubating.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.zookeeper_zookeeper-3.4.6.jar at spark://localhost:40393/jars/org.apache.zookeeper_zookeeper-3.4.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.jamesmurty.utils_java-xmlbuilder-0.4.jar at spark://localhost:40393/jars/com.jamesmurty.utils_java-xmlbuilder-0.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-digester_commons-digester-1.8.jar at spark://localhost:40393/jars/commons-digester_commons-digester-1.8.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-beanutils_commons-beanutils-core-1.8.0.jar at spark://localhost:40393/jars/commons-beanutils_commons-beanutils-core-1.8.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-beanutils_commons-beanutils-1.7.0.jar at spark://localhost:40393/jars/commons-beanutils_commons-beanutils-1.7.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.directory.server_apacheds-kerberos-codec-2.0.0-M15.jar at spark://localhost:40393/jars/org.apache.directory.server_apacheds-kerberos-codec-2.0.0-M15.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.curator_curator-framework-2.7.1.jar at spark://localhost:40393/jars/org.apache.curator_curator-framework-2.7.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.directory.server_apacheds-i18n-2.0.0-M15.jar at spark://localhost:40393/jars/org.apache.directory.server_apacheds-i18n-2.0.0-M15.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.directory.api_api-asn1-api-1.0.0-M20.jar at spark://localhost:40393/jars/org.apache.directory.api_api-asn1-api-1.0.0-M20.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.directory.api_api-util-1.0.0-M20.jar at spark://localhost:40393/jars/org.apache.directory.api_api-util-1.0.0-M20.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/javax.servlet.jsp_jsp-api-2.1.jar at spark://localhost:40393/jars/javax.servlet.jsp_jsp-api-2.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.httpcomponents_httpclient-4.5.2.jar at spark://localhost:40393/jars/org.apache.httpcomponents_httpclient-4.5.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.eclipse.jetty_jetty-util-ajax-9.3.24.v20180605.jar at spark://localhost:40393/jars/org.eclipse.jetty_jetty-util-ajax-9.3.24.v20180605.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.wildfly.openssl_wildfly-openssl-1.0.4.Final.jar at spark://localhost:40393/jars/org.wildfly.openssl_wildfly-openssl-1.0.4.Final.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.httpcomponents_httpcore-4.4.4.jar at spark://localhost:40393/jars/org.apache.httpcomponents_httpcore-4.4.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-codec_commons-codec-1.11.jar at spark://localhost:40393/jars/commons-codec_commons-codec-1.11.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.commons_commons-compress-1.8.1.jar at spark://localhost:40393/jars/org.apache.commons_commons-compress-1.8.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.1.3.jar at spark://localhost:40393/jars/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.1.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-eventhubs-3.3.0.jar at spark://localhost:40393/jars/com.microsoft.azure_azure-eventhubs-3.3.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.scala-lang.modules_scala-java8-compat_2.12-0.9.0.jar at spark://localhost:40393/jars/org.scala-lang.modules_scala-java8-compat_2.12-0.9.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.qpid_proton-j-0.33.8.jar at spark://localhost:40393/jars/org.apache.qpid_proton-j-0.33.8.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_qpid-proton-j-extensions-1.2.4.jar at spark://localhost:40393/jars/com.microsoft.azure_qpid-proton-j-extensions-1.2.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-client-authentication-1.7.3.jar at spark://localhost:40393/jars/com.microsoft.azure_azure-client-authentication-1.7.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.nimbusds_nimbus-jose-jwt-9.8.1.jar at spark://localhost:40393/jars/com.nimbusds_nimbus-jose-jwt-9.8.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-client-runtime-1.7.3.jar at spark://localhost:40393/jars/com.microsoft.azure_azure-client-runtime-1.7.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_adal4j-1.6.4.jar at spark://localhost:40393/jars/com.microsoft.azure_adal4j-1.6.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-annotations-1.10.0.jar at spark://localhost:40393/jars/com.microsoft.azure_azure-annotations-1.10.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.rest_client-runtime-1.7.3.jar at spark://localhost:40393/jars/com.microsoft.rest_client-runtime-1.7.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.squareup.retrofit2_retrofit-2.7.2.jar at spark://localhost:40393/jars/com.squareup.retrofit2_retrofit-2.7.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.squareup.okhttp3_okhttp-3.12.6.jar at spark://localhost:40393/jars/com.squareup.okhttp3_okhttp-3.12.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.squareup.okhttp3_logging-interceptor-3.12.2.jar at spark://localhost:40393/jars/com.squareup.okhttp3_logging-interceptor-3.12.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.squareup.okhttp3_okhttp-urlconnection-3.12.2.jar at spark://localhost:40393/jars/com.squareup.okhttp3_okhttp-urlconnection-3.12.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.squareup.retrofit2_converter-jackson-2.7.2.jar at spark://localhost:40393/jars/com.squareup.retrofit2_converter-jackson-2.7.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.datatype_jackson-datatype-joda-2.10.1.jar at spark://localhost:40393/jars/com.fasterxml.jackson.datatype_jackson-datatype-joda-2.10.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/io.reactivex_rxjava-1.3.8.jar at spark://localhost:40393/jars/io.reactivex_rxjava-1.3.8.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.squareup.retrofit2_adapter-rxjava-2.7.2.jar at spark://localhost:40393/jars/com.squareup.retrofit2_adapter-rxjava-2.7.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.squareup.okio_okio-1.15.0.jar at spark://localhost:40393/jars/com.squareup.okio_okio-1.15.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/joda-time_joda-time-2.9.9.jar at spark://localhost:40393/jars/joda-time_joda-time-2.9.9.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.nimbusds_oauth2-oidc-sdk-6.5.jar at spark://localhost:40393/jars/com.nimbusds_oauth2-oidc-sdk-6.5.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.code.gson_gson-2.8.0.jar at spark://localhost:40393/jars/com.google.code.gson_gson-2.8.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.sun.mail_javax.mail-1.6.1.jar at spark://localhost:40393/jars/com.sun.mail_javax.mail-1.6.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.github.stephenc.jcip_jcip-annotations-1.0-1.jar at spark://localhost:40393/jars/com.github.stephenc.jcip_jcip-annotations-1.0-1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/net.minidev_json-smart-2.3.jar at spark://localhost:40393/jars/net.minidev_json-smart-2.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.nimbusds_lang-tag-1.7.jar at spark://localhost:40393/jars/com.nimbusds_lang-tag-1.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/net.minidev_accessors-smart-1.2.jar at spark://localhost:40393/jars/net.minidev_accessors-smart-1.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.ow2.asm_asm-5.0.4.jar at spark://localhost:40393/jars/org.ow2.asm_asm-5.0.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.github.luben_zstd-jni-1.5.0-4.jar at spark://localhost:40393/jars/com.github.luben_zstd-jni-1.5.0-4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.lz4_lz4-java-1.8.0.jar at spark://localhost:40393/jars/org.lz4_lz4-java-1.8.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar at spark://localhost:40393/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.guava_failureaccess-1.0.1.jar at spark://localhost:40393/jars/com.google.guava_failureaccess-1.0.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar at spark://localhost:40393/jars/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.code.findbugs_jsr305-3.0.2.jar at spark://localhost:40393/jars/com.google.code.findbugs_jsr305-3.0.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.checkerframework_checker-qual-3.12.0.jar at spark://localhost:40393/jars/org.checkerframework_checker-qual-3.12.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.errorprone_error_prone_annotations-2.11.0.jar at spark://localhost:40393/jars/com.google.errorprone_error_prone_annotations-2.11.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.j2objc_j2objc-annotations-1.3.jar at spark://localhost:40393/jars/com.google.j2objc_j2objc-annotations-1.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-core-2.13.3.jar at spark://localhost:40393/jars/com.fasterxml.jackson.core_jackson-core-2.13.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-annotations-2.13.3.jar at spark://localhost:40393/jars/com.fasterxml.jackson.core_jackson-annotations-2.13.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-databind-2.13.3.jar at spark://localhost:40393/jars/com.fasterxml.jackson.core_jackson-databind-2.13.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.thoughtworks.paranamer_paranamer-2.8.jar at spark://localhost:40393/jars/com.thoughtworks.paranamer_paranamer-2.8.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.yaml_snakeyaml-1.27.jar at spark://localhost:40393/jars/org.yaml_snakeyaml-1.27.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/redis.clients_jedis-3.9.0.jar at spark://localhost:40393/jars/redis.clients_jedis-3.9.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.commons_commons-pool2-2.11.1.jar at spark://localhost:40393/jars/org.apache.commons_commons-pool2-2.11.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/net.snowflake_snowflake-ingest-sdk-0.10.3.jar at spark://localhost:40393/jars/net.snowflake_snowflake-ingest-sdk-0.10.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.scala-lang_scala-reflect-2.12.10.jar at spark://localhost:40393/jars/org.scala-lang_scala-reflect-2.12.10.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.module_jackson-module-paranamer-2.9.8.jar at spark://localhost:40393/jars/com.fasterxml.jackson.module_jackson-module-paranamer-2.9.8.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.36.jar at spark://localhost:40393/jars/org.slf4j_slf4j-api-1.7.36.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-keyvault-core-1.0.0.jar at spark://localhost:40393/jars/com.microsoft.azure_azure-keyvault-core-1.0.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-avro_2.12-3.3.0.jar at spark://localhost:40393/files/org.apache.spark_spark-avro_2.12-3.3.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.spark_spark-avro_2.12-3.3.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.spark_spark-avro_2.12-3.3.0.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar at spark://localhost:40393/files/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar at spark://localhost:40393/files/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.logging.log4j_log4j-core-2.17.2.jar at spark://localhost:40393/files/org.apache.logging.log4j_log4j-core-2.17.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.logging.log4j_log4j-core-2.17.2.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.logging.log4j_log4j-core-2.17.2.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.typesafe_config-1.3.4.jar at spark://localhost:40393/files/com.typesafe_config-1.3.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.typesafe_config-1.3.4.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.typesafe_config-1.3.4.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar at spark://localhost:40393/files/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-common-2.7.7.jar at spark://localhost:40393/files/org.apache.hadoop_hadoop-common-2.7.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-common-2.7.7.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.hadoop_hadoop-common-2.7.7.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-azure-3.2.0.jar at spark://localhost:40393/files/org.apache.hadoop_hadoop-azure-3.2.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-azure-3.2.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.hadoop_hadoop-azure-3.2.0.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.avro_avro-1.8.2.jar at spark://localhost:40393/files/org.apache.avro_avro-1.8.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.avro_avro-1.8.2.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.avro_avro-1.8.2.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.xbean_xbean-asm6-shaded-4.10.jar at spark://localhost:40393/files/org.apache.xbean_xbean-asm6-shaded-4.10.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.xbean_xbean-asm6-shaded-4.10.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.xbean_xbean-asm6-shaded-4.10.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.1.3.jar at spark://localhost:40393/files/org.apache.spark_spark-sql-kafka-0-10_2.12-3.1.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.1.3.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.spark_spark-sql-kafka-0-10_2.12-3.1.3.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-eventhubs-spark_2.12-2.3.21.jar at spark://localhost:40393/files/com.microsoft.azure_azure-eventhubs-spark_2.12-2.3.21.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.microsoft.azure_azure-eventhubs-spark_2.12-2.3.21.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.microsoft.azure_azure-eventhubs-spark_2.12-2.3.21.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.kafka_kafka-clients-3.1.0.jar at spark://localhost:40393/files/org.apache.kafka_kafka-clients-3.1.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.kafka_kafka-clients-3.1.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.kafka_kafka-clients-3.1.0.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.google.guava_guava-31.1-jre.jar at spark://localhost:40393/files/com.google.guava_guava-31.1-jre.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.google.guava_guava-31.1-jre.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.google.guava_guava-31.1-jre.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/it.unimi.dsi_fastutil-8.1.1.jar at spark://localhost:40393/files/it.unimi.dsi_fastutil-8.1.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/it.unimi.dsi_fastutil-8.1.1.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/it.unimi.dsi_fastutil-8.1.1.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.mvel_mvel2-2.2.8.Final.jar at spark://localhost:40393/files/org.mvel_mvel2-2.2.8.Final.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.mvel_mvel2-2.2.8.Final.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.mvel_mvel2-2.2.8.Final.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.module_jackson-module-scala_2.12-2.13.3.jar at spark://localhost:40393/files/com.fasterxml.jackson.module_jackson-module-scala_2.12-2.13.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.fasterxml.jackson.module_jackson-module-scala_2.12-2.13.3.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.fasterxml.jackson.module_jackson-module-scala_2.12-2.13.3.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-yaml-2.12.6.jar at spark://localhost:40393/files/com.fasterxml.jackson.dataformat_jackson-dataformat-yaml-2.12.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-yaml-2.12.6.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.fasterxml.jackson.dataformat_jackson-dataformat-yaml-2.12.6.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar at spark://localhost:40393/files/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.jasonclawson_jackson-dataformat-hocon-1.1.0.jar at spark://localhost:40393/files/com.jasonclawson_jackson-dataformat-hocon-1.1.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.jasonclawson_jackson-dataformat-hocon-1.1.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.jasonclawson_jackson-dataformat-hocon-1.1.0.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.redislabs_spark-redis_2.12-3.1.0.jar at spark://localhost:40393/files/com.redislabs_spark-redis_2.12-3.1.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.redislabs_spark-redis_2.12-3.1.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.redislabs_spark-redis_2.12-3.1.0.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.google.protobuf_protobuf-java-3.19.4.jar at spark://localhost:40393/files/com.google.protobuf_protobuf-java-3.19.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.google.protobuf_protobuf-java-3.19.4.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.google.protobuf_protobuf-java-3.19.4.jar
# ...
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/net.minidev_accessors-smart-1.2.jar at spark://localhost:40393/files/net.minidev_accessors-smart-1.2.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/net.minidev_accessors-smart-1.2.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/net.minidev_accessors-smart-1.2.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.ow2.asm_asm-5.0.4.jar at spark://localhost:40393/files/org.ow2.asm_asm-5.0.4.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.ow2.asm_asm-5.0.4.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.ow2.asm_asm-5.0.4.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.github.luben_zstd-jni-1.5.0-4.jar at spark://localhost:40393/files/com.github.luben_zstd-jni-1.5.0-4.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.github.luben_zstd-jni-1.5.0-4.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.github.luben_zstd-jni-1.5.0-4.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.lz4_lz4-java-1.8.0.jar at spark://localhost:40393/files/org.lz4_lz4-java-1.8.0.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.lz4_lz4-java-1.8.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.lz4_lz4-java-1.8.0.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar at spark://localhost:40393/files/org.xerial.snappy_snappy-java-1.1.8.4.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.xerial.snappy_snappy-java-1.1.8.4.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.google.guava_failureaccess-1.0.1.jar at spark://localhost:40393/files/com.google.guava_failureaccess-1.0.1.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.google.guava_failureaccess-1.0.1.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.google.guava_failureaccess-1.0.1.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar at spark://localhost:40393/files/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.google.code.findbugs_jsr305-3.0.2.jar at spark://localhost:40393/files/com.google.code.findbugs_jsr305-3.0.2.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.google.code.findbugs_jsr305-3.0.2.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.google.code.findbugs_jsr305-3.0.2.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.checkerframework_checker-qual-3.12.0.jar at spark://localhost:40393/files/org.checkerframework_checker-qual-3.12.0.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.checkerframework_checker-qual-3.12.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.checkerframework_checker-qual-3.12.0.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.google.errorprone_error_prone_annotations-2.11.0.jar at spark://localhost:40393/files/com.google.errorprone_error_prone_annotations-2.11.0.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.google.errorprone_error_prone_annotations-2.11.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.google.errorprone_error_prone_annotations-2.11.0.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.google.j2objc_j2objc-annotations-1.3.jar at spark://localhost:40393/files/com.google.j2objc_j2objc-annotations-1.3.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.google.j2objc_j2objc-annotations-1.3.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.google.j2objc_j2objc-annotations-1.3.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-core-2.13.3.jar at spark://localhost:40393/files/com.fasterxml.jackson.core_jackson-core-2.13.3.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-core-2.13.3.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.fasterxml.jackson.core_jackson-core-2.13.3.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-annotations-2.13.3.jar at spark://localhost:40393/files/com.fasterxml.jackson.core_jackson-annotations-2.13.3.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-annotations-2.13.3.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.fasterxml.jackson.core_jackson-annotations-2.13.3.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-databind-2.13.3.jar at spark://localhost:40393/files/com.fasterxml.jackson.core_jackson-databind-2.13.3.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-databind-2.13.3.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.fasterxml.jackson.core_jackson-databind-2.13.3.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.thoughtworks.paranamer_paranamer-2.8.jar at spark://localhost:40393/files/com.thoughtworks.paranamer_paranamer-2.8.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.thoughtworks.paranamer_paranamer-2.8.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.thoughtworks.paranamer_paranamer-2.8.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.yaml_snakeyaml-1.27.jar at spark://localhost:40393/files/org.yaml_snakeyaml-1.27.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.yaml_snakeyaml-1.27.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.yaml_snakeyaml-1.27.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/redis.clients_jedis-3.9.0.jar at spark://localhost:40393/files/redis.clients_jedis-3.9.0.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/redis.clients_jedis-3.9.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/redis.clients_jedis-3.9.0.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.commons_commons-pool2-2.11.1.jar at spark://localhost:40393/files/org.apache.commons_commons-pool2-2.11.1.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.commons_commons-pool2-2.11.1.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.commons_commons-pool2-2.11.1.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/net.snowflake_snowflake-ingest-sdk-0.10.3.jar at spark://localhost:40393/files/net.snowflake_snowflake-ingest-sdk-0.10.3.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/net.snowflake_snowflake-ingest-sdk-0.10.3.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/net.snowflake_snowflake-ingest-sdk-0.10.3.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.scala-lang_scala-reflect-2.12.10.jar at spark://localhost:40393/files/org.scala-lang_scala-reflect-2.12.10.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.scala-lang_scala-reflect-2.12.10.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.scala-lang_scala-reflect-2.12.10.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.module_jackson-module-paranamer-2.9.8.jar at spark://localhost:40393/files/com.fasterxml.jackson.module_jackson-module-paranamer-2.9.8.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.fasterxml.jackson.module_jackson-module-paranamer-2.9.8.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.fasterxml.jackson.module_jackson-module-paranamer-2.9.8.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.36.jar at spark://localhost:40393/files/org.slf4j_slf4j-api-1.7.36.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.36.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.slf4j_slf4j-api-1.7.36.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-keyvault-core-1.0.0.jar at spark://localhost:40393/files/com.microsoft.azure_azure-keyvault-core-1.0.0.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.microsoft.azure_azure-keyvault-core-1.0.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.microsoft.azure_azure-keyvault-core-1.0.0.jar
# 23/08/30 22:36:37 INFO StandaloneAppClient$ClientEndpoint: Connecting to master spark://spark-master:7077...
# 23/08/30 22:36:37 INFO TransportClientFactory: Successfully created connection to spark-master/172.20.0.4:7077 after 20 ms (0 ms spent in bootstraps)
# 23/08/30 22:36:37 INFO StandaloneSchedulerBackend: Connected to Spark cluster with app ID app-20230830223637-0001
# 23/08/30 22:36:37 INFO StandaloneAppClient$ClientEndpoint: Executor added: app-20230830223637-0001/0 on worker-20230830213748-172.20.0.5-40787 (172.20.0.5:40787) with 12 core(s)
# 23/08/30 22:36:37 INFO StandaloneSchedulerBackend: Granted executor ID app-20230830223637-0001/0 on hostPort 172.20.0.5:40787 with 12 core(s), 1024.0 MiB RAM
# 23/08/30 22:36:37 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 35677.
# 23/08/30 22:36:37 INFO NettyBlockTransferService: Server created on localhost:35677
# 23/08/30 22:36:37 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 23/08/30 22:36:37 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, localhost, 35677, None)
# 23/08/30 22:36:37 INFO BlockManagerMasterEndpoint: Registering block manager localhost:35677 with 434.4 MiB RAM, BlockManagerId(driver, localhost, 35677, None)
# 23/08/30 22:36:37 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, localhost, 35677, None)
# 23/08/30 22:36:37 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, localhost, 35677, None)
# 23/08/30 22:36:37 INFO StandaloneAppClient$ClientEndpoint: Executor updated: app-20230830223637-0001/0 is now RUNNING
# 23/08/30 22:36:37 INFO StandaloneSchedulerBackend: SchedulerBackend is ready for scheduling beginning after reached minRegisteredResourcesRatio: 0.0
# pyspark_client.py: Preprocessing via UDFs and submit Spark job.
# FeatureJoinConfig is provided. Executing FeatureJoinJob.
# submit_spark_job: feature_names_funcs:
# {'feature_user_age,feature_user_gift_card_balance,feature_user_has_valid_credit_card,feature_user_tax_rate': <function feathr_udf_preprocessing at 0x7fd614fcdaf0>}
# set(feature_names_funcs.keys()):
# {'feature_user_age,feature_user_gift_card_balance,feature_user_has_valid_credit_card,feature_user_tax_rate'}
# submit_spark_job: Load DataFrame from Scala engine.
# Traceback (most recent call last):
#   File "/tmp/tmpvxf4ut1g/feathr_pyspark_driver.py", line 107, in <module>
#     submit_spark_job(feature_names_funcs)
#   File "/tmp/tmpvxf4ut1g/feathr_pyspark_driver.py", line 64, in submit_spark_job
#     dataframeFromSpark = py4j_feature_job.loadSourceDataframe(
# TypeError: 'JavaPackage' object is not callable
# 23/08/30 22:36:38 INFO SparkContext: Invoking stop() from shutdown hook
# 23/08/30 22:36:38 INFO SparkUI: Stopped Spark web UI at http://localhost:4040
# 23/08/30 22:36:38 INFO StandaloneSchedulerBackend: Shutting down all executors
# 23/08/30 22:36:38 INFO CoarseGrainedSchedulerBackend$DriverEndpoint: Asking each executor to shut down
# 23/08/30 22:36:38 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 23/08/30 22:36:38 INFO MemoryStore: MemoryStore cleared
# 23/08/30 22:36:38 INFO BlockManager: BlockManager stopped
# 23/08/30 22:36:38 INFO BlockManagerMaster: BlockManagerMaster stopped
# 23/08/30 22:36:38 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 23/08/30 22:36:38 INFO SparkContext: Successfully stopped SparkContext
# 23/08/30 22:36:38 INFO ShutdownHookManager: Shutdown hook called
# 23/08/30 22:36:38 INFO ShutdownHookManager: Deleting directory /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce
# 23/08/30 22:36:38 INFO ShutdownHookManager: Deleting directory /tmp/spark-6c3e322d-553c-42bb-9931-bdbde75db822
# 23/08/30 22:36:38 INFO ShutdownHookManager: Deleting directory /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/pyspark-b1f58390-6ded-4b82-83f5-adb1c6cbb2d9
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [16], line 21
#      11 settings = ObservationSettings(
#      12     observation_path=user_observation_source_path,
#      13     event_timestamp_column="event_timestamp",
#      14     timestamp_format="yyyy-MM-dd",
#      15 )
#      16 client.get_offline_features(
#      17     observation_settings=settings,
#      18     feature_query=[user_feature_query, product_feature_query],
#      19     output_path=user_profile_source_path.rpartition("/")[0] + f"/product_recommendation_features.avro",
#      20 )
# ---> 21 client.wait_job_to_finish(timeout_sec=100)
#
# File /opt/conda/lib/python3.9/site-packages/feathr/client.py:965, in FeathrClient.wait_job_to_finish(self, timeout_sec)
#     963     return
#     964 else:
# --> 965     raise RuntimeError("Spark job failed.")
#
# RuntimeError: Spark job failed.

# %% [markdown]
# Let's use the helper function `get_result_df` to download the result and view it:

# %%
res_df = get_result_df(client)
res_df.head()
# Out:
# 2023-08-30 22:41:04.014 | INFO     | feathr.spark_provider._localspark_submission:wait_for_completion:162 - 1 local spark job(s) in this Launcher, only the latest will be monitored.
# 2023-08-30 22:41:04.016 | INFO     | feathr.spark_provider._localspark_submission:wait_for_completion:163 - Please check auto generated spark command in debug/local_spark_feathr_feature_join_job20230830223622/command.sh and detail logs in debug/local_spark_feathr_feature_join_job20230830223622/log.
# 2023-08-30 22:41:04.017 | WARNING  | feathr.spark_provider._localspark_submission:wait_for_completion:212 - Spark job with pid 4282 is not successful. Spark Logs:
# 2023-08-30 22:41:04.018 | ERROR    | feathr.spark_provider._localspark_submission:wait_for_completion:215 - :: loading settings :: url = jar:file:/usr/local/spark-3.3.0-bin-hadoop3/jars/ivy-2.5.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# 23/08/30 22:36:34 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Feathr Pyspark job started.
# 23/08/30 22:36:36 INFO SparkContext: Running Spark version 3.3.0
# 23/08/30 22:36:36 INFO ResourceUtils: ==============================================================
# 23/08/30 22:36:36 INFO ResourceUtils: No custom resources configured for spark.driver.
# 23/08/30 22:36:36 INFO ResourceUtils: ==============================================================
# 23/08/30 22:36:36 INFO SparkContext: Submitted application: FeathrPyspark
# 23/08/30 22:36:36 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 23/08/30 22:36:36 INFO ResourceProfile: Limiting resource is cpu
# 23/08/30 22:36:36 INFO ResourceProfileManager: Added ResourceProfile id: 0
# 23/08/30 22:36:36 INFO SecurityManager: Changing view acls to: jovyan
# 23/08/30 22:36:36 INFO SecurityManager: Changing modify acls to: jovyan
# 23/08/30 22:36:36 INFO SecurityManager: Changing view acls groups to:
# 23/08/30 22:36:36 INFO SecurityManager: Changing modify acls groups to:
# 23/08/30 22:36:36 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(jovyan); groups with view permissions: Set(); users  with modify permissions: Set(jovyan); groups with modify permissions: Set()
# 23/08/30 22:36:36 INFO Utils: Successfully started service 'sparkDriver' on port 40393.
# 23/08/30 22:36:36 INFO SparkEnv: Registering MapOutputTracker
# 23/08/30 22:36:36 INFO SparkEnv: Registering BlockManagerMaster
# 23/08/30 22:36:36 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 23/08/30 22:36:36 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 23/08/30 22:36:36 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
# 23/08/30 22:36:36 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-ae5413c0-076f-4619-8e7b-1bfe42a3746b
# 23/08/30 22:36:36 INFO MemoryStore: MemoryStore started with capacity 434.4 MiB
# 23/08/30 22:36:36 INFO SparkEnv: Registering OutputCommitCoordinator
# 23/08/30 22:36:36 INFO Utils: Successfully started service 'SparkUI' on port 4040.
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-avro_2.12-3.3.0.jar at spark://localhost:40393/jars/org.apache.spark_spark-avro_2.12-3.3.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar at spark://localhost:40393/jars/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar at spark://localhost:40393/jars/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.logging.log4j_log4j-core-2.17.2.jar at spark://localhost:40393/jars/org.apache.logging.log4j_log4j-core-2.17.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.typesafe_config-1.3.4.jar at spark://localhost:40393/jars/com.typesafe_config-1.3.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar at spark://localhost:40393/jars/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-common-2.7.7.jar at spark://localhost:40393/jars/org.apache.hadoop_hadoop-common-2.7.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-azure-3.2.0.jar at spark://localhost:40393/jars/org.apache.hadoop_hadoop-azure-3.2.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.avro_avro-1.8.2.jar at spark://localhost:40393/jars/org.apache.avro_avro-1.8.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.xbean_xbean-asm6-shaded-4.10.jar at spark://localhost:40393/jars/org.apache.xbean_xbean-asm6-shaded-4.10.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.1.3.jar at spark://localhost:40393/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.1.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-eventhubs-spark_2.12-2.3.21.jar at spark://localhost:40393/jars/com.microsoft.azure_azure-eventhubs-spark_2.12-2.3.21.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.kafka_kafka-clients-3.1.0.jar at spark://localhost:40393/jars/org.apache.kafka_kafka-clients-3.1.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.guava_guava-31.1-jre.jar at spark://localhost:40393/jars/com.google.guava_guava-31.1-jre.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/it.unimi.dsi_fastutil-8.1.1.jar at spark://localhost:40393/jars/it.unimi.dsi_fastutil-8.1.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.mvel_mvel2-2.2.8.Final.jar at spark://localhost:40393/jars/org.mvel_mvel2-2.2.8.Final.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.module_jackson-module-scala_2.12-2.13.3.jar at spark://localhost:40393/jars/com.fasterxml.jackson.module_jackson-module-scala_2.12-2.13.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-yaml-2.12.6.jar at spark://localhost:40393/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-yaml-2.12.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar at spark://localhost:40393/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.jasonclawson_jackson-dataformat-hocon-1.1.0.jar at spark://localhost:40393/jars/com.jasonclawson_jackson-dataformat-hocon-1.1.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.redislabs_spark-redis_2.12-3.1.0.jar at spark://localhost:40393/jars/com.redislabs_spark-redis_2.12-3.1.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.protobuf_protobuf-java-3.19.4.jar at spark://localhost:40393/jars/com.google.protobuf_protobuf-java-3.19.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/net.snowflake_snowflake-jdbc-3.13.18.jar at spark://localhost:40393/jars/net.snowflake_snowflake-jdbc-3.13.18.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/net.snowflake_spark-snowflake_2.12-2.10.0-spark_3.2.jar at spark://localhost:40393/jars/net.snowflake_spark-snowflake_2.12-2.10.0-spark_3.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.commons_commons-lang3-3.12.0.jar at spark://localhost:40393/jars/org.apache.commons_commons-lang3-3.12.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.xerial_sqlite-jdbc-3.36.0.3.jar at spark://localhost:40393/jars/org.xerial_sqlite-jdbc-3.36.0.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.github.changvvb_jackson-module-caseclass_2.12-1.1.1.jar at spark://localhost:40393/jars/com.github.changvvb_jackson-module-caseclass_2.12-1.1.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.azure.cosmos.spark_azure-cosmos-spark_3-1_2-12-4.11.1.jar at spark://localhost:40393/jars/com.azure.cosmos.spark_azure-cosmos-spark_3-1_2-12-4.11.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.eclipse.jetty_jetty-util-9.3.24.v20180605.jar at spark://localhost:40393/jars/org.eclipse.jetty_jetty-util-9.3.24.v20180605.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-io_commons-io-2.6.jar at spark://localhost:40393/jars/commons-io_commons-io-2.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-storage-8.6.4.jar at spark://localhost:40393/jars/com.microsoft.azure_azure-storage-8.6.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.tukaani_xz-1.8.jar at spark://localhost:40393/jars/org.tukaani_xz-1.8.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.spark-project.spark_unused-1.0.0.jar at spark://localhost:40393/jars/org.spark-project.spark_unused-1.0.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar at spark://localhost:40393/jars/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.slf4j_slf4j-log4j12-1.7.10.jar at spark://localhost:40393/jars/org.slf4j_slf4j-log4j12-1.7.10.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-annotations-2.7.7.jar at spark://localhost:40393/jars/org.apache.hadoop_hadoop-annotations-2.7.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.inject.extensions_guice-servlet-3.0.jar at spark://localhost:40393/jars/com.google.inject.extensions_guice-servlet-3.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/io.netty_netty-3.6.2.Final.jar at spark://localhost:40393/jars/io.netty_netty-3.6.2.Final.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-yarn-api-2.7.7.jar at spark://localhost:40393/jars/org.apache.hadoop_hadoop-yarn-api-2.7.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/javax.xml.bind_jaxb-api-2.2.2.jar at spark://localhost:40393/jars/javax.xml.bind_jaxb-api-2.2.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-lang_commons-lang-2.6.jar at spark://localhost:40393/jars/commons-lang_commons-lang-2.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/javax.servlet_servlet-api-2.5.jar at spark://localhost:40393/jars/javax.servlet_servlet-api-2.5.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.mortbay.jetty_jetty-util-6.1.26.jar at spark://localhost:40393/jars/org.mortbay.jetty_jetty-util-6.1.26.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.sun.jersey_jersey-core-1.9.jar at spark://localhost:40393/jars/com.sun.jersey_jersey-core-1.9.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.sun.jersey_jersey-client-1.9.jar at spark://localhost:40393/jars/com.sun.jersey_jersey-client-1.9.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.codehaus.jackson_jackson-core-asl-1.9.13.jar at spark://localhost:40393/jars/org.codehaus.jackson_jackson-core-asl-1.9.13.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.codehaus.jackson_jackson-mapper-asl-1.9.13.jar at spark://localhost:40393/jars/org.codehaus.jackson_jackson-mapper-asl-1.9.13.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.codehaus.jackson_jackson-jaxrs-1.9.13.jar at spark://localhost:40393/jars/org.codehaus.jackson_jackson-jaxrs-1.9.13.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.codehaus.jackson_jackson-xc-1.9.13.jar at spark://localhost:40393/jars/org.codehaus.jackson_jackson-xc-1.9.13.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-logging_commons-logging-1.1.3.jar at spark://localhost:40393/jars/commons-logging_commons-logging-1.1.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-cli_commons-cli-1.2.jar at spark://localhost:40393/jars/commons-cli_commons-cli-1.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.inject_guice-3.0.jar at spark://localhost:40393/jars/com.google.inject_guice-3.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.sun.jersey_jersey-server-1.9.jar at spark://localhost:40393/jars/com.sun.jersey_jersey-server-1.9.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.sun.jersey_jersey-json-1.9.jar at spark://localhost:40393/jars/com.sun.jersey_jersey-json-1.9.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.sun.jersey.contribs_jersey-guice-1.9.jar at spark://localhost:40393/jars/com.sun.jersey.contribs_jersey-guice-1.9.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/log4j_log4j-1.2.17.jar at spark://localhost:40393/jars/log4j_log4j-1.2.17.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/javax.xml.stream_stax-api-1.0-2.jar at spark://localhost:40393/jars/javax.xml.stream_stax-api-1.0-2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/javax.activation_activation-1.1.jar at spark://localhost:40393/jars/javax.activation_activation-1.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/javax.inject_javax.inject-1.jar at spark://localhost:40393/jars/javax.inject_javax.inject-1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/aopalliance_aopalliance-1.0.jar at spark://localhost:40393/jars/aopalliance_aopalliance-1.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.sonatype.sisu.inject_cglib-2.2.1-v20090111.jar at spark://localhost:40393/jars/org.sonatype.sisu.inject_cglib-2.2.1-v20090111.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/asm_asm-3.2.jar at spark://localhost:40393/jars/asm_asm-3.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.codehaus.jettison_jettison-1.1.jar at spark://localhost:40393/jars/org.codehaus.jettison_jettison-1.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.sun.xml.bind_jaxb-impl-2.2.3-1.jar at spark://localhost:40393/jars/com.sun.xml.bind_jaxb-impl-2.2.3-1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.commons_commons-math3-3.1.1.jar at spark://localhost:40393/jars/org.apache.commons_commons-math3-3.1.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/xmlenc_xmlenc-0.52.jar at spark://localhost:40393/jars/xmlenc_xmlenc-0.52.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-httpclient_commons-httpclient-3.1.jar at spark://localhost:40393/jars/commons-httpclient_commons-httpclient-3.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-net_commons-net-3.1.jar at spark://localhost:40393/jars/commons-net_commons-net-3.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-collections_commons-collections-3.2.2.jar at spark://localhost:40393/jars/commons-collections_commons-collections-3.2.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.mortbay.jetty_jetty-6.1.26.jar at spark://localhost:40393/jars/org.mortbay.jetty_jetty-6.1.26.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.mortbay.jetty_jetty-sslengine-6.1.26.jar at spark://localhost:40393/jars/org.mortbay.jetty_jetty-sslengine-6.1.26.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/net.java.dev.jets3t_jets3t-0.9.0.jar at spark://localhost:40393/jars/net.java.dev.jets3t_jets3t-0.9.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-configuration_commons-configuration-1.6.jar at spark://localhost:40393/jars/commons-configuration_commons-configuration-1.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-auth-2.7.7.jar at spark://localhost:40393/jars/org.apache.hadoop_hadoop-auth-2.7.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.jcraft_jsch-0.1.54.jar at spark://localhost:40393/jars/com.jcraft_jsch-0.1.54.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.curator_curator-client-2.7.1.jar at spark://localhost:40393/jars/org.apache.curator_curator-client-2.7.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.curator_curator-recipes-2.7.1.jar at spark://localhost:40393/jars/org.apache.curator_curator-recipes-2.7.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.htrace_htrace-core-3.1.0-incubating.jar at spark://localhost:40393/jars/org.apache.htrace_htrace-core-3.1.0-incubating.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.zookeeper_zookeeper-3.4.6.jar at spark://localhost:40393/jars/org.apache.zookeeper_zookeeper-3.4.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.jamesmurty.utils_java-xmlbuilder-0.4.jar at spark://localhost:40393/jars/com.jamesmurty.utils_java-xmlbuilder-0.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-digester_commons-digester-1.8.jar at spark://localhost:40393/jars/commons-digester_commons-digester-1.8.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-beanutils_commons-beanutils-core-1.8.0.jar at spark://localhost:40393/jars/commons-beanutils_commons-beanutils-core-1.8.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-beanutils_commons-beanutils-1.7.0.jar at spark://localhost:40393/jars/commons-beanutils_commons-beanutils-1.7.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.directory.server_apacheds-kerberos-codec-2.0.0-M15.jar at spark://localhost:40393/jars/org.apache.directory.server_apacheds-kerberos-codec-2.0.0-M15.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.curator_curator-framework-2.7.1.jar at spark://localhost:40393/jars/org.apache.curator_curator-framework-2.7.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.directory.server_apacheds-i18n-2.0.0-M15.jar at spark://localhost:40393/jars/org.apache.directory.server_apacheds-i18n-2.0.0-M15.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.directory.api_api-asn1-api-1.0.0-M20.jar at spark://localhost:40393/jars/org.apache.directory.api_api-asn1-api-1.0.0-M20.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.directory.api_api-util-1.0.0-M20.jar at spark://localhost:40393/jars/org.apache.directory.api_api-util-1.0.0-M20.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/javax.servlet.jsp_jsp-api-2.1.jar at spark://localhost:40393/jars/javax.servlet.jsp_jsp-api-2.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.httpcomponents_httpclient-4.5.2.jar at spark://localhost:40393/jars/org.apache.httpcomponents_httpclient-4.5.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.eclipse.jetty_jetty-util-ajax-9.3.24.v20180605.jar at spark://localhost:40393/jars/org.eclipse.jetty_jetty-util-ajax-9.3.24.v20180605.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.wildfly.openssl_wildfly-openssl-1.0.4.Final.jar at spark://localhost:40393/jars/org.wildfly.openssl_wildfly-openssl-1.0.4.Final.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.httpcomponents_httpcore-4.4.4.jar at spark://localhost:40393/jars/org.apache.httpcomponents_httpcore-4.4.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-codec_commons-codec-1.11.jar at spark://localhost:40393/jars/commons-codec_commons-codec-1.11.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.commons_commons-compress-1.8.1.jar at spark://localhost:40393/jars/org.apache.commons_commons-compress-1.8.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.1.3.jar at spark://localhost:40393/jars/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.1.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-eventhubs-3.3.0.jar at spark://localhost:40393/jars/com.microsoft.azure_azure-eventhubs-3.3.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.scala-lang.modules_scala-java8-compat_2.12-0.9.0.jar at spark://localhost:40393/jars/org.scala-lang.modules_scala-java8-compat_2.12-0.9.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.qpid_proton-j-0.33.8.jar at spark://localhost:40393/jars/org.apache.qpid_proton-j-0.33.8.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_qpid-proton-j-extensions-1.2.4.jar at spark://localhost:40393/jars/com.microsoft.azure_qpid-proton-j-extensions-1.2.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-client-authentication-1.7.3.jar at spark://localhost:40393/jars/com.microsoft.azure_azure-client-authentication-1.7.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.nimbusds_nimbus-jose-jwt-9.8.1.jar at spark://localhost:40393/jars/com.nimbusds_nimbus-jose-jwt-9.8.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-client-runtime-1.7.3.jar at spark://localhost:40393/jars/com.microsoft.azure_azure-client-runtime-1.7.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_adal4j-1.6.4.jar at spark://localhost:40393/jars/com.microsoft.azure_adal4j-1.6.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-annotations-1.10.0.jar at spark://localhost:40393/jars/com.microsoft.azure_azure-annotations-1.10.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.rest_client-runtime-1.7.3.jar at spark://localhost:40393/jars/com.microsoft.rest_client-runtime-1.7.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.squareup.retrofit2_retrofit-2.7.2.jar at spark://localhost:40393/jars/com.squareup.retrofit2_retrofit-2.7.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.squareup.okhttp3_okhttp-3.12.6.jar at spark://localhost:40393/jars/com.squareup.okhttp3_okhttp-3.12.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.squareup.okhttp3_logging-interceptor-3.12.2.jar at spark://localhost:40393/jars/com.squareup.okhttp3_logging-interceptor-3.12.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.squareup.okhttp3_okhttp-urlconnection-3.12.2.jar at spark://localhost:40393/jars/com.squareup.okhttp3_okhttp-urlconnection-3.12.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.squareup.retrofit2_converter-jackson-2.7.2.jar at spark://localhost:40393/jars/com.squareup.retrofit2_converter-jackson-2.7.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.datatype_jackson-datatype-joda-2.10.1.jar at spark://localhost:40393/jars/com.fasterxml.jackson.datatype_jackson-datatype-joda-2.10.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/io.reactivex_rxjava-1.3.8.jar at spark://localhost:40393/jars/io.reactivex_rxjava-1.3.8.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.squareup.retrofit2_adapter-rxjava-2.7.2.jar at spark://localhost:40393/jars/com.squareup.retrofit2_adapter-rxjava-2.7.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.squareup.okio_okio-1.15.0.jar at spark://localhost:40393/jars/com.squareup.okio_okio-1.15.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/joda-time_joda-time-2.9.9.jar at spark://localhost:40393/jars/joda-time_joda-time-2.9.9.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.nimbusds_oauth2-oidc-sdk-6.5.jar at spark://localhost:40393/jars/com.nimbusds_oauth2-oidc-sdk-6.5.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.code.gson_gson-2.8.0.jar at spark://localhost:40393/jars/com.google.code.gson_gson-2.8.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.sun.mail_javax.mail-1.6.1.jar at spark://localhost:40393/jars/com.sun.mail_javax.mail-1.6.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.github.stephenc.jcip_jcip-annotations-1.0-1.jar at spark://localhost:40393/jars/com.github.stephenc.jcip_jcip-annotations-1.0-1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/net.minidev_json-smart-2.3.jar at spark://localhost:40393/jars/net.minidev_json-smart-2.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.nimbusds_lang-tag-1.7.jar at spark://localhost:40393/jars/com.nimbusds_lang-tag-1.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/net.minidev_accessors-smart-1.2.jar at spark://localhost:40393/jars/net.minidev_accessors-smart-1.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.ow2.asm_asm-5.0.4.jar at spark://localhost:40393/jars/org.ow2.asm_asm-5.0.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.github.luben_zstd-jni-1.5.0-4.jar at spark://localhost:40393/jars/com.github.luben_zstd-jni-1.5.0-4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.lz4_lz4-java-1.8.0.jar at spark://localhost:40393/jars/org.lz4_lz4-java-1.8.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar at spark://localhost:40393/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.guava_failureaccess-1.0.1.jar at spark://localhost:40393/jars/com.google.guava_failureaccess-1.0.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar at spark://localhost:40393/jars/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.code.findbugs_jsr305-3.0.2.jar at spark://localhost:40393/jars/com.google.code.findbugs_jsr305-3.0.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.checkerframework_checker-qual-3.12.0.jar at spark://localhost:40393/jars/org.checkerframework_checker-qual-3.12.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.errorprone_error_prone_annotations-2.11.0.jar at spark://localhost:40393/jars/com.google.errorprone_error_prone_annotations-2.11.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.j2objc_j2objc-annotations-1.3.jar at spark://localhost:40393/jars/com.google.j2objc_j2objc-annotations-1.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-core-2.13.3.jar at spark://localhost:40393/jars/com.fasterxml.jackson.core_jackson-core-2.13.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-annotations-2.13.3.jar at spark://localhost:40393/jars/com.fasterxml.jackson.core_jackson-annotations-2.13.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-databind-2.13.3.jar at spark://localhost:40393/jars/com.fasterxml.jackson.core_jackson-databind-2.13.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.thoughtworks.paranamer_paranamer-2.8.jar at spark://localhost:40393/jars/com.thoughtworks.paranamer_paranamer-2.8.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.yaml_snakeyaml-1.27.jar at spark://localhost:40393/jars/org.yaml_snakeyaml-1.27.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/redis.clients_jedis-3.9.0.jar at spark://localhost:40393/jars/redis.clients_jedis-3.9.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.commons_commons-pool2-2.11.1.jar at spark://localhost:40393/jars/org.apache.commons_commons-pool2-2.11.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/net.snowflake_snowflake-ingest-sdk-0.10.3.jar at spark://localhost:40393/jars/net.snowflake_snowflake-ingest-sdk-0.10.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.scala-lang_scala-reflect-2.12.10.jar at spark://localhost:40393/jars/org.scala-lang_scala-reflect-2.12.10.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.module_jackson-module-paranamer-2.9.8.jar at spark://localhost:40393/jars/com.fasterxml.jackson.module_jackson-module-paranamer-2.9.8.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.36.jar at spark://localhost:40393/jars/org.slf4j_slf4j-api-1.7.36.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-keyvault-core-1.0.0.jar at spark://localhost:40393/jars/com.microsoft.azure_azure-keyvault-core-1.0.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-avro_2.12-3.3.0.jar at spark://localhost:40393/files/org.apache.spark_spark-avro_2.12-3.3.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.spark_spark-avro_2.12-3.3.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.spark_spark-avro_2.12-3.3.0.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar at spark://localhost:40393/files/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.microsoft.sqlserver_mssql-jdbc-10.2.0.jre8.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar at spark://localhost:40393/files/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.microsoft.azure_spark-mssql-connector_2.12-1.2.0.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.logging.log4j_log4j-core-2.17.2.jar at spark://localhost:40393/files/org.apache.logging.log4j_log4j-core-2.17.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.logging.log4j_log4j-core-2.17.2.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.logging.log4j_log4j-core-2.17.2.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.typesafe_config-1.3.4.jar at spark://localhost:40393/files/com.typesafe_config-1.3.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.typesafe_config-1.3.4.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.typesafe_config-1.3.4.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar at spark://localhost:40393/files/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-common-2.7.7.jar at spark://localhost:40393/files/org.apache.hadoop_hadoop-common-2.7.7.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-common-2.7.7.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.hadoop_hadoop-common-2.7.7.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-azure-3.2.0.jar at spark://localhost:40393/files/org.apache.hadoop_hadoop-azure-3.2.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-azure-3.2.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.hadoop_hadoop-azure-3.2.0.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.avro_avro-1.8.2.jar at spark://localhost:40393/files/org.apache.avro_avro-1.8.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.avro_avro-1.8.2.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.avro_avro-1.8.2.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.xbean_xbean-asm6-shaded-4.10.jar at spark://localhost:40393/files/org.apache.xbean_xbean-asm6-shaded-4.10.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.xbean_xbean-asm6-shaded-4.10.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.xbean_xbean-asm6-shaded-4.10.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.1.3.jar at spark://localhost:40393/files/org.apache.spark_spark-sql-kafka-0-10_2.12-3.1.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.1.3.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.spark_spark-sql-kafka-0-10_2.12-3.1.3.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-eventhubs-spark_2.12-2.3.21.jar at spark://localhost:40393/files/com.microsoft.azure_azure-eventhubs-spark_2.12-2.3.21.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.microsoft.azure_azure-eventhubs-spark_2.12-2.3.21.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.microsoft.azure_azure-eventhubs-spark_2.12-2.3.21.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.kafka_kafka-clients-3.1.0.jar at spark://localhost:40393/files/org.apache.kafka_kafka-clients-3.1.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.kafka_kafka-clients-3.1.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.kafka_kafka-clients-3.1.0.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.google.guava_guava-31.1-jre.jar at spark://localhost:40393/files/com.google.guava_guava-31.1-jre.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.google.guava_guava-31.1-jre.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.google.guava_guava-31.1-jre.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/it.unimi.dsi_fastutil-8.1.1.jar at spark://localhost:40393/files/it.unimi.dsi_fastutil-8.1.1.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/it.unimi.dsi_fastutil-8.1.1.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/it.unimi.dsi_fastutil-8.1.1.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.mvel_mvel2-2.2.8.Final.jar at spark://localhost:40393/files/org.mvel_mvel2-2.2.8.Final.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.mvel_mvel2-2.2.8.Final.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.mvel_mvel2-2.2.8.Final.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.module_jackson-module-scala_2.12-2.13.3.jar at spark://localhost:40393/files/com.fasterxml.jackson.module_jackson-module-scala_2.12-2.13.3.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.fasterxml.jackson.module_jackson-module-scala_2.12-2.13.3.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.fasterxml.jackson.module_jackson-module-scala_2.12-2.13.3.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-yaml-2.12.6.jar at spark://localhost:40393/files/com.fasterxml.jackson.dataformat_jackson-dataformat-yaml-2.12.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-yaml-2.12.6.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.fasterxml.jackson.dataformat_jackson-dataformat-yaml-2.12.6.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar at spark://localhost:40393/files/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.fasterxml.jackson.dataformat_jackson-dataformat-csv-2.12.6.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.jasonclawson_jackson-dataformat-hocon-1.1.0.jar at spark://localhost:40393/files/com.jasonclawson_jackson-dataformat-hocon-1.1.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.jasonclawson_jackson-dataformat-hocon-1.1.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.jasonclawson_jackson-dataformat-hocon-1.1.0.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.redislabs_spark-redis_2.12-3.1.0.jar at spark://localhost:40393/files/com.redislabs_spark-redis_2.12-3.1.0.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.redislabs_spark-redis_2.12-3.1.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.redislabs_spark-redis_2.12-3.1.0.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.google.protobuf_protobuf-java-3.19.4.jar at spark://localhost:40393/files/com.google.protobuf_protobuf-java-3.19.4.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.google.protobuf_protobuf-java-3.19.4.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.google.protobuf_protobuf-java-3.19.4.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/net.snowflake_snowflake-jdbc-3.13.18.jar at spark://localhost:40393/files/net.snowflake_snowflake-jdbc-3.13.18.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/net.snowflake_snowflake-jdbc-3.13.18.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/net.snowflake_snowflake-jdbc-3.13.18.jar
# 23/08/30 22:36:36 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/net.snowflake_spark-snowflake_2.12-2.10.0-spark_3.2.jar at spark://localhost:40393/files/net.snowflake_spark-snowflake_2.12-2.10.0-spark_3.2.jar with timestamp 1693434996117
# 23/08/30 22:36:36 INFO Utils: Copying /home/jovyan/.ivy2/jars/net.snowflake_spark-snowflake_2.12-2.10.0-spark_3.2.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/net.snowflake_spark-snowflake_2.12-2.10.0-spark_3.2.jar
# ...
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.ow2.asm_asm-5.0.4.jar at spark://localhost:40393/files/org.ow2.asm_asm-5.0.4.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.ow2.asm_asm-5.0.4.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.ow2.asm_asm-5.0.4.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.github.luben_zstd-jni-1.5.0-4.jar at spark://localhost:40393/files/com.github.luben_zstd-jni-1.5.0-4.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.github.luben_zstd-jni-1.5.0-4.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.github.luben_zstd-jni-1.5.0-4.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.lz4_lz4-java-1.8.0.jar at spark://localhost:40393/files/org.lz4_lz4-java-1.8.0.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.lz4_lz4-java-1.8.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.lz4_lz4-java-1.8.0.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar at spark://localhost:40393/files/org.xerial.snappy_snappy-java-1.1.8.4.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.xerial.snappy_snappy-java-1.1.8.4.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.google.guava_failureaccess-1.0.1.jar at spark://localhost:40393/files/com.google.guava_failureaccess-1.0.1.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.google.guava_failureaccess-1.0.1.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.google.guava_failureaccess-1.0.1.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar at spark://localhost:40393/files/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.google.guava_listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.google.code.findbugs_jsr305-3.0.2.jar at spark://localhost:40393/files/com.google.code.findbugs_jsr305-3.0.2.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.google.code.findbugs_jsr305-3.0.2.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.google.code.findbugs_jsr305-3.0.2.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.checkerframework_checker-qual-3.12.0.jar at spark://localhost:40393/files/org.checkerframework_checker-qual-3.12.0.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.checkerframework_checker-qual-3.12.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.checkerframework_checker-qual-3.12.0.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.google.errorprone_error_prone_annotations-2.11.0.jar at spark://localhost:40393/files/com.google.errorprone_error_prone_annotations-2.11.0.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.google.errorprone_error_prone_annotations-2.11.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.google.errorprone_error_prone_annotations-2.11.0.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.google.j2objc_j2objc-annotations-1.3.jar at spark://localhost:40393/files/com.google.j2objc_j2objc-annotations-1.3.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.google.j2objc_j2objc-annotations-1.3.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.google.j2objc_j2objc-annotations-1.3.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-core-2.13.3.jar at spark://localhost:40393/files/com.fasterxml.jackson.core_jackson-core-2.13.3.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-core-2.13.3.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.fasterxml.jackson.core_jackson-core-2.13.3.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-annotations-2.13.3.jar at spark://localhost:40393/files/com.fasterxml.jackson.core_jackson-annotations-2.13.3.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-annotations-2.13.3.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.fasterxml.jackson.core_jackson-annotations-2.13.3.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-databind-2.13.3.jar at spark://localhost:40393/files/com.fasterxml.jackson.core_jackson-databind-2.13.3.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.fasterxml.jackson.core_jackson-databind-2.13.3.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.fasterxml.jackson.core_jackson-databind-2.13.3.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.thoughtworks.paranamer_paranamer-2.8.jar at spark://localhost:40393/files/com.thoughtworks.paranamer_paranamer-2.8.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.thoughtworks.paranamer_paranamer-2.8.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.thoughtworks.paranamer_paranamer-2.8.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.yaml_snakeyaml-1.27.jar at spark://localhost:40393/files/org.yaml_snakeyaml-1.27.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.yaml_snakeyaml-1.27.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.yaml_snakeyaml-1.27.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/redis.clients_jedis-3.9.0.jar at spark://localhost:40393/files/redis.clients_jedis-3.9.0.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/redis.clients_jedis-3.9.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/redis.clients_jedis-3.9.0.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.commons_commons-pool2-2.11.1.jar at spark://localhost:40393/files/org.apache.commons_commons-pool2-2.11.1.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.commons_commons-pool2-2.11.1.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.apache.commons_commons-pool2-2.11.1.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/net.snowflake_snowflake-ingest-sdk-0.10.3.jar at spark://localhost:40393/files/net.snowflake_snowflake-ingest-sdk-0.10.3.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/net.snowflake_snowflake-ingest-sdk-0.10.3.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/net.snowflake_snowflake-ingest-sdk-0.10.3.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.scala-lang_scala-reflect-2.12.10.jar at spark://localhost:40393/files/org.scala-lang_scala-reflect-2.12.10.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.scala-lang_scala-reflect-2.12.10.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.scala-lang_scala-reflect-2.12.10.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.fasterxml.jackson.module_jackson-module-paranamer-2.9.8.jar at spark://localhost:40393/files/com.fasterxml.jackson.module_jackson-module-paranamer-2.9.8.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.fasterxml.jackson.module_jackson-module-paranamer-2.9.8.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.fasterxml.jackson.module_jackson-module-paranamer-2.9.8.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.36.jar at spark://localhost:40393/files/org.slf4j_slf4j-api-1.7.36.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.36.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/org.slf4j_slf4j-api-1.7.36.jar
# 23/08/30 22:36:37 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.microsoft.azure_azure-keyvault-core-1.0.0.jar at spark://localhost:40393/files/com.microsoft.azure_azure-keyvault-core-1.0.0.jar with timestamp 1693434996117
# 23/08/30 22:36:37 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.microsoft.azure_azure-keyvault-core-1.0.0.jar to /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/userFiles-586622ec-fdec-470f-955f-65e0d4d8bfa0/com.microsoft.azure_azure-keyvault-core-1.0.0.jar
# 23/08/30 22:36:37 INFO StandaloneAppClient$ClientEndpoint: Connecting to master spark://spark-master:7077...
# 23/08/30 22:36:37 INFO TransportClientFactory: Successfully created connection to spark-master/172.20.0.4:7077 after 20 ms (0 ms spent in bootstraps)
# 23/08/30 22:36:37 INFO StandaloneSchedulerBackend: Connected to Spark cluster with app ID app-20230830223637-0001
# 23/08/30 22:36:37 INFO StandaloneAppClient$ClientEndpoint: Executor added: app-20230830223637-0001/0 on worker-20230830213748-172.20.0.5-40787 (172.20.0.5:40787) with 12 core(s)
# 23/08/30 22:36:37 INFO StandaloneSchedulerBackend: Granted executor ID app-20230830223637-0001/0 on hostPort 172.20.0.5:40787 with 12 core(s), 1024.0 MiB RAM
# 23/08/30 22:36:37 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 35677.
# 23/08/30 22:36:37 INFO NettyBlockTransferService: Server created on localhost:35677
# 23/08/30 22:36:37 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 23/08/30 22:36:37 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, localhost, 35677, None)
# 23/08/30 22:36:37 INFO BlockManagerMasterEndpoint: Registering block manager localhost:35677 with 434.4 MiB RAM, BlockManagerId(driver, localhost, 35677, None)
# 23/08/30 22:36:37 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, localhost, 35677, None)
# 23/08/30 22:36:37 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, localhost, 35677, None)
# 23/08/30 22:36:37 INFO StandaloneAppClient$ClientEndpoint: Executor updated: app-20230830223637-0001/0 is now RUNNING
# 23/08/30 22:36:37 INFO StandaloneSchedulerBackend: SchedulerBackend is ready for scheduling beginning after reached minRegisteredResourcesRatio: 0.0
# pyspark_client.py: Preprocessing via UDFs and submit Spark job.
# FeatureJoinConfig is provided. Executing FeatureJoinJob.
# submit_spark_job: feature_names_funcs:
# {'feature_user_age,feature_user_gift_card_balance,feature_user_has_valid_credit_card,feature_user_tax_rate': <function feathr_udf_preprocessing at 0x7fd614fcdaf0>}
# set(feature_names_funcs.keys()):
# {'feature_user_age,feature_user_gift_card_balance,feature_user_has_valid_credit_card,feature_user_tax_rate'}
# submit_spark_job: Load DataFrame from Scala engine.
# Traceback (most recent call last):
#   File "/tmp/tmpvxf4ut1g/feathr_pyspark_driver.py", line 107, in <module>
#     submit_spark_job(feature_names_funcs)
#   File "/tmp/tmpvxf4ut1g/feathr_pyspark_driver.py", line 64, in submit_spark_job
#     dataframeFromSpark = py4j_feature_job.loadSourceDataframe(
# TypeError: 'JavaPackage' object is not callable
# 23/08/30 22:36:38 INFO SparkContext: Invoking stop() from shutdown hook
# 23/08/30 22:36:38 INFO SparkUI: Stopped Spark web UI at http://localhost:4040
# 23/08/30 22:36:38 INFO StandaloneSchedulerBackend: Shutting down all executors
# 23/08/30 22:36:38 INFO CoarseGrainedSchedulerBackend$DriverEndpoint: Asking each executor to shut down
# 23/08/30 22:36:38 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 23/08/30 22:36:38 INFO MemoryStore: MemoryStore cleared
# 23/08/30 22:36:38 INFO BlockManager: BlockManager stopped
# 23/08/30 22:36:38 INFO BlockManagerMaster: BlockManagerMaster stopped
# 23/08/30 22:36:38 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 23/08/30 22:36:38 INFO SparkContext: Successfully stopped SparkContext
# 23/08/30 22:36:38 INFO ShutdownHookManager: Shutdown hook called
# 23/08/30 22:36:38 INFO ShutdownHookManager: Deleting directory /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce
# 23/08/30 22:36:38 INFO ShutdownHookManager: Deleting directory /tmp/spark-6c3e322d-553c-42bb-9931-bdbde75db822
# 23/08/30 22:36:38 INFO ShutdownHookManager: Deleting directory /tmp/spark-83d3be5e-7227-4265-b71e-91a91a98a7ce/pyspark-b1f58390-6ded-4b82-83f5-adb1c6cbb2d9
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 res_df = get_result_df(client)
#       2 res_df.head()
#
# File /opt/conda/lib/python3.9/site-packages/feathr/utils/job_utils.py:121, in get_result_df(client, data_format, res_url, local_cache_path, spark, format, is_file_path)
#     116     raise RuntimeError(
#     117         f"Loading Delta table result from Azure Synapse into pandas DataFrame is not supported. You maybe able to use spark DataFrame to load the result instead."
#     118     )
#     120 # use a result url if it's provided by the user, otherwise use the one provided by the job
# --> 121 res_url: str = res_url or client.get_job_result_uri(block=True, timeout_sec=1200)
#     122 if res_url is None:
#     123     raise ValueError(
#     124         "`res_url` is None. Please make sure either you provide a res_url or make sure the job finished in FeathrClient has a valid result URI."
#     125     )
#
# File /opt/conda/lib/python3.9/site-packages/feathr/client.py:712, in FeathrClient.get_job_result_uri(self, block, timeout_sec)
#     710     return self.feathr_spark_launcher.get_job_result_uri()
#     711 else:
# --> 712     raise RuntimeError("Spark job failed so output cannot be retrieved.")
#
# RuntimeError: Spark job failed so output cannot be retrieved.

# %% [markdown]
# ### Train a machine learning model
# After getting all the features, let's train a machine learning model with the converted feature by Feathr. Here, we use **EBM (Explainable Boosting Machine)** regressor from [InterpretML](https://github.com/interpretml/interpret) package to visualize the modeling results.

# %%
from interpret import show
from interpret.glassbox import ExplainableBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Fill None values with 0
final_df = (
    res_df
    .drop(["event_timestamp"], axis=1, errors="ignore")
    .fillna(0)
)

# Split data into train and test
X_train, X_test, y_train, y_test = train_test_split(
    final_df.drop(["product_rating"], axis=1),
    final_df["product_rating"].astype("float64"),
    test_size=0.2,
    random_state=42,
)

ebm = ExplainableBoostingRegressor()
ebm.fit(X_train, y_train)

# show(ebm_global) # Will run on 127.0.0.1/localhost at port 7080
# Note, currently InterpretML's visualization dashboard doesn't work w/ VSCODE notebook viewer
# https://github.com/interpretml/interpret/issues/317
ebm_global = ebm.explain_global()
show(ebm_global)

# %%
# Predict and evaluate
y_pred = ebm.predict(X_test)
rmse = sqrt(mean_squared_error(y_test.values.flatten(), y_pred))

print(f"Root mean squared error: {rmse}")

# %% [markdown]
# ## 6. Feature Materialization
#
# While Feathr can compute the feature value from the feature definition on-the-fly at request time, it can also pre-compute
# and materialize the feature value to offline and/or online storage.
#
# We can push the generated features to the online store like below:

# %%
# Materialize user features
# Note, you can only materialize features of same entity key into one table.
redisSink = RedisSink(table_name="user_features")
settings = MaterializationSettings(
    name="user_feature_setting",
    sinks=[redisSink],
    feature_names=["feature_user_age", "feature_user_gift_card_balance"],
)

client.materialize_features(settings=settings, allow_materialize_non_agg_feature=True)
client.wait_job_to_finish(timeout_sec=100)

# %% [markdown]
# We can then get the features from the online store (Redis):

# %%
client.get_online_features(
    "user_features", "2", ["feature_user_age", "feature_user_gift_card_balance"]
)

# %%
client.multi_get_online_features(
    "user_features", ["1", "2"], ["feature_user_age", "feature_user_gift_card_balance"]
)

# %% [markdown]
# ## 7. Feature Registration
# We can also register the features and share them across teams:

# %%
try:
    client.register_features()
except Exception as e:
    print(e)
print(client.list_registered_features(project_name=PROJECT_NAME))

# %% [markdown]
# You should be able to see the Feathr UI by visiting the website below:
#
# http://localhost:8081/

# %%
from IPython.display import IFrame
IFrame("http://localhost:8081/projects", 900,500)

# %% [markdown]
# ## 8. Chat with Feathr (Experimental, powered by ChatGPT)
# First, let's setup the API_KEY for ChatGPT. You can find your api key at https://platform.openai.com/account/api-keys.

# %%
os.environ['CHATGPT_API_KEY'] = 'YOUR_CHAT_GPT_API_KEY'

# %% [markdown]
# Load 'feathr' chat magic

# %%
# %reload_ext feathr.chat

# %% [markdown]
# Start chat!

# %%
# %feathr "What are the available features"

# %%
# %feathr "What are the available data sources"

# %%
# %feathr "Create a feature tax_rate_demical = tax_rate/100"

# %%
# %feathr "Join feature tax_rate_demical with my observation data in point-in-time manner"

# %%
# %feathr "Materialize my feature tax_rate_demical"

# %% [markdown]
# ## Cleanup

# %%
# Cleaning up the output files. CAUTION: this maybe dangerous if you "reused" the project name.
import shutil
shutil.rmtree(WORKING_DIR, ignore_errors=False)
